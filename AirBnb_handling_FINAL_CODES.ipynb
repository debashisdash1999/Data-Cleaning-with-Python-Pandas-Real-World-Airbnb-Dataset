# %%
# Step: Perform a data cleaning or inspection operation
# Why: This step improves data quality before further processing

import pandas as pd

# %%
# Step: Load raw Airbnb CSV data into a pandas DataFrame
# Why: This initializes the dataset so we can inspect and clean it further

data = pd.read_csv("Airbnb_Open_Data.CSV")
# Out:
# C:\Users\choud\AppData\Local\Temp\ipykernel_19856\3689506724.py:1: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("Airbnb_Open_Data.CSV")

# %%
# Step: Perform a data cleaning or inspection operation
# Why: This step improves data quality before further processing

data.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ... service fee minimum nights  \
# ...

# %%
# Step: View column names of the dataset
# Why: Helps understand schema and identify columns that need renaming or cleaning

data.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
# Step: Inspect data types and non-null counts
# Why: Used to detect missing values and incorrect data types early

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102349 non-null  object
#  2   host id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  object
#  4   host name                       102193 non-null  object
#  5   neighbourhood group             102570 non-null  object
#  6   neighbourhood                   102583 non-null  object
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  object
#  10  country code                    102468 non-null  object
#  11  instant_bookable                102494 non-null  object
# ...

# %%
# Step: Perform a data cleaning or inspection operation
# Why: This step improves data quality before further processing

data["license"]
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 102594    NaN
# 102595    NaN
# 102596    NaN
# 102597    NaN
# 102598    NaN
# Name: license, Length: 102599, dtype: object

# %%
# Step: Perform a data cleaning or inspection operation
# Why: This step improves data quality before further processing

data
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
# Step: Perform a data cleaning or inspection operation
# Why: This step improves data quality before further processing

columns_to_keep = ['NAME', 'host id', 'host_identity_verified', 'host name',
       'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
       'country code', 'instant_bookable', 'cancellation_policy', 'room type',
       'Construction year', 'price', 'service fee', 'minimum nights',
       'number of reviews', 'last review']
columns_to_drop = ['id', 'reviews per month',
       'review rate number', 'calculated host listings count',
       'availability 365', 'house_rules', 'license']

# %%
# Step: Perform a data cleaning or inspection operation
# Why: This step improves data quality before further processing

len(columns_to_keep)
# Out:
# 19

# %%
# Step: Perform a data cleaning or inspection operation
# Why: This step improves data quality before further processing

len(columns_to_drop)
# Out:
# 7

# %% [markdown]
# # 1st Method, Filtering Data

# %%
# Step: Perform a data cleaning or inspection operation
# Why: This step improves data quality before further processing

df = data[columns_to_keep]

# %%
# Step: Perform a data cleaning or inspection operation
# Why: This step improves data quality before further processing

df
# Out:
#                                                     NAME      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# ...

# %% [markdown]
# # 2nd Method, Dropping Columns

# %%
# Step: Perform a data cleaning or inspection operation
# Why: This step improves data quality before further processing

data.drop(columns = columns_to_drop,inplace = True)

# %%
# Step: Perform a data cleaning or inspection operation
# Why: This step improves data quality before further processing

data.shape
# Out:
# (102599, 19)

# %%
# Step: Perform a data cleaning or inspection operation
# Why: This step improves data quality before further processing

data
# Out:
#                                                     NAME      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# ...

# %% [markdown]
# # Renaming the required columns

# %%
# Step: View column names of the dataset
# Why: Helps understand schema and identify columns that need renaming or cleaning

data.columns
# Out:
# Index(['NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review'],
#       dtype='object')

# %%
# Step: Rename columns for clarity and consistency
# Why: Improves readability and maintainability of the dataset

data.rename(columns= {"NAME": "Name"}, inplace = True)

# %%
# Step: Perform a data cleaning or inspection operation
# Why: This step improves data quality before further processing

data
# Out:
#                                                     Name      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# ...

# %%
# Step: Perform a data cleaning or inspection operation
# Why: This step improves data quality before further processing

new_columns_names = []
for i in data.columns:
    new_columns_names.append(i.upper())

# %%
# Step: Perform a data cleaning or inspection operation
# Why: This step improves data quality before further processing

type(new_columns_names)
# Out:
# list

# %%
# Step: Perform a data cleaning or inspection operation
# Why: This step improves data quality before further processing

new_columns_names
# Out:
# ['NAME',
#  'HOST ID',
#  'HOST_IDENTITY_VERIFIED',
#  'HOST NAME',
#  'NEIGHBOURHOOD GROUP',
#  'NEIGHBOURHOOD',
#  'LAT',
#  'LONG',
#  'COUNTRY',
#  'COUNTRY CODE',
#  'INSTANT_BOOKABLE',
#  'CANCELLATION_POLICY',
#  'ROOM TYPE',
#  'CONSTRUCTION YEAR',
#  'PRICE',
#  'SERVICE FEE',
#  'MINIMUM NIGHTS',
#  'NUMBER OF REVIEWS',
#  'LAST REVIEW']

# %%
# Step: Perform a data cleaning or inspection operation
# Why: This step improves data quality before further processing

new_dataframe_to_modify = data.copy()

# %%
# Step: View column names of the dataset
# Why: Helps understand schema and identify columns that need renaming or cleaning

new_dataframe_to_modify.columns = new_columns_names

# %%
# Step: Perform a data cleaning or inspection operation
# Why: This step improves data quality before further processing

new_dataframe_to_modify
# Out:
#                                                     NAME      HOST ID  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        HOST_IDENTITY_VERIFIED    HOST NAME NEIGHBOURHOOD GROUP  \
# ...

# %% [markdown]
# # Dropping duplicates

# %%
# Step: Identify duplicate records
# Why: Helps detect repeated entries that can bias analysis

data.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 102594     True
# 102595     True
# 102596     True
# 102597     True
# 102598     True
# Length: 102599, dtype: bool

# %%
# Step: Identify duplicate records
# Why: Helps detect repeated entries that can bias analysis

data.duplicated().value_counts()
# Out:
# False    102058
# True        541
# Name: count, dtype: int64

# %%
# Step: Identify duplicate records
# Why: Helps detect repeated entries that can bias analysis

data.duplicated().sum()
# Out:
# np.int64(541)

# %%
# Step: Remove duplicate rows from the dataset
# Why: Ensures each record is unique and reliable

data.drop_duplicates(inplace = True)

# %%
# Step: Identify duplicate records
# Why: Helps detect repeated entries that can bias analysis

data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Removing the NaN values from dataset

# %%
# Step: Perform a data cleaning or inspection operation
# Why: This step improves data quality before further processing

data
# Out:
#                                                     Name      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102053               Cozy bright room near Prospect Park  77326652202
# 102054         Private Bedroom with Amazing Rooftop View  45936254757
# 102055     Pretty Brooklyn One-Bedroom for 2 to 4 people  23801060917
# 102056        Room & private bathroom in historic Harlem  15593031571
# 102057                                   Rosalee Stewart  93578954226
#
#        host_identity_verified host name neighbourhood group  \
# 0                 unconfirmed  Madaline            Brooklyn
# ...

# %%
# Step: Check for missing values in the dataset
# Why: Identifies columns that require null handling strategies

data.isna().sum()
# Out:
# Name                        250
# host id                       0
# host_identity_verified      289
# host name                   404
# neighbourhood group          29
# neighbourhood                16
# lat                           8
# long                          8
# country                     532
# country code                131
# instant_bookable            105
# cancellation_policy          76
# room type                     0
# Construction year           214
# price                       247
# service fee                 273
# minimum nights              400
# number of reviews           183
# last review               15832
# dtype: int64

# %%
# Step: Perform a data cleaning or inspection operation
# Why: This step improves data quality before further processing

data.drop(columns=["last review"], inplace=True)

# %%
# Step: Check for missing values in the dataset
# Why: Identifies columns that require null handling strategies

data.isna().sum()
# Out:
# Name                      250
# host id                     0
# host_identity_verified    289
# host name                 404
# neighbourhood group        29
# neighbourhood              16
# lat                         8
# long                        8
# country                   532
# country code              131
# instant_bookable          105
# cancellation_policy        76
# room type                   0
# Construction year         214
# price                     247
# service fee               273
# minimum nights            400
# number of reviews         183
# dtype: int64

# %%
# Step: Remove rows or columns with excessive missing data
# Why: Eliminates low-quality data that adds noise to analysis

data.dropna(inplace=True)

# %%
# Step: Check for missing values in the dataset
# Why: Identifies columns that require null handling strategies

data.isna().sum()
# Out:
# Name                      0
# host id                   0
# host_identity_verified    0
# host name                 0
# neighbourhood group       0
# neighbourhood             0
# lat                       0
# long                      0
# country                   0
# country code              0
# instant_bookable          0
# cancellation_policy       0
# room type                 0
# Construction year         0
# price                     0
# service fee               0
# minimum nights            0
# number of reviews         0
# dtype: int64

# %% [markdown]
# # Cleaning individual columns

# %%
# Step: Perform a data cleaning or inspection operation
# Why: This step improves data quality before further processing

data
# Out:
#                                                     Name      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5              Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                        BlissArtsSpace!  90821839709
# ...                                                  ...          ...
# 102029            Cozy room in a 2B with backyard access   5155155913
# 102030                      An East Williamsburg Delight  71564706996
# 102031                      Cozy bedroom in williamsburg  83101851929
# 102032                            Spacious Room w/ 2 Bed  69037598918
# 102040                     Room in Queens, NY, near LGA.  56457739998
#
#        host_identity_verified  host name neighbourhood group  \
# 0                 unconfirmed   Madaline            Brooklyn
# ...

# %%
# Step: Perform a data cleaning or inspection operation
# Why: This step improves data quality before further processing

data["host_identity_verified"].str.upper()
# Out:
# 0         UNCONFIRMED
# 1            VERIFIED
# 4            VERIFIED
# 5            VERIFIED
# 7         UNCONFIRMED
#              ...
# 102029    UNCONFIRMED
# 102030       VERIFIED
# 102031       VERIFIED
# 102032    UNCONFIRMED
# 102040       VERIFIED
# Name: host_identity_verified, Length: 99342, dtype: object

# %%
# Step: Perform a data cleaning or inspection operation
# Why: This step improves data quality before further processing

data["host_identity_verified"] = data["host_identity_verified"].str.upper()

# %%
# Step: Perform a data cleaning or inspection operation
# Why: This step improves data quality before further processing

data
# Out:
#                                                     Name      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5              Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                        BlissArtsSpace!  90821839709
# ...                                                  ...          ...
# 102029            Cozy room in a 2B with backyard access   5155155913
# 102030                      An East Williamsburg Delight  71564706996
# 102031                      Cozy bedroom in williamsburg  83101851929
# 102032                            Spacious Room w/ 2 Bed  69037598918
# 102040                     Room in Queens, NY, near LGA.  56457739998
#
#        host_identity_verified  host name neighbourhood group  \
# 0                 UNCONFIRMED   Madaline            Brooklyn
# ...

# %%
# Step: Perform a data cleaning or inspection operation
# Why: This step improves data quality before further processing

data["instant_bookable"].apply(lambda x: 1 if x == True else 0)
# Out:
# 0         0
# 1         0
# 4         0
# 5         1
# 7         0
#          ..
# 102029    0
# 102030    1
# 102031    1
# 102032    0
# 102040    1
# Name: instant_bookable, Length: 99342, dtype: int64

# %%
# Step: Perform a data cleaning or inspection operation
# Why: This step improves data quality before further processing

data["instant_bookable"] = data["instant_bookable"].apply(lambda x: 1 if x == True else 0)

# %%
# Step: Perform a data cleaning or inspection operation
# Why: This step improves data quality before further processing

data.reset_index(inplace= True)

# %%
# Step: Perform a data cleaning or inspection operation
# Why: This step improves data quality before further processing

data
# Out:
#         index                                              Name      host id  \
# 0           0                Clean & quiet apt home by the park  80014485718
# 1           1                             Skylit Midtown Castle  52335172823
# 2           4  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3           5         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4           7                                   BlissArtsSpace!  90821839709
# ...       ...                                               ...          ...
# 99337  102029            Cozy room in a 2B with backyard access   5155155913
# 99338  102030                      An East Williamsburg Delight  71564706996
# 99339  102031                      Cozy bedroom in williamsburg  83101851929
# 99340  102032                            Spacious Room w/ 2 Bed  69037598918
# 99341  102040                     Room in Queens, NY, near LGA.  56457739998
#
# ...

# %%
# Step: Perform a data cleaning or inspection operation
# Why: This step improves data quality before further processing

type(data["instant_bookable"] [5])
# Out:
# numpy.int64

# %%
# Step: Perform a data cleaning or inspection operation
# Why: This step improves data quality before further processing

type(data["instant_bookable"] [15])
# Out:
# numpy.int64

# %% [markdown]
# # some more operations

# %%
# Step: Perform a data cleaning or inspection operation
# Why: This step improves data quality before further processing

type(data["price"] [15])
# Out:
# str

# %%
# Step: Perform a data cleaning or inspection operation
# Why: This step improves data quality before further processing

data["price"].head(3)
# Out:
# 0    $966
# 1    $142
# 2    $204
# Name: price, dtype: object

# %%
# Step: Perform a data cleaning or inspection operation
# Why: This step improves data quality before further processing

data["price"].str.replace("$", "")
# Out:
# 0          966
# 1          142
# 2          204
# 3          577
# 4        1,060
#           ...
# 99337      822
# 99338      455
# 99339    1,078
# 99340      103
# 99341      982
# Name: price, Length: 99342, dtype: object

# %%
# Step: Perform a data cleaning or inspection operation
# Why: This step improves data quality before further processing

data["price"] = data["price"].str.replace("$", "")

# %%
# Step: Perform a data cleaning or inspection operation
# Why: This step improves data quality before further processing

data["price"]
# Out:
# 0          966
# 1          142
# 2          204
# 3          577
# 4        1,060
#           ...
# 99337      822
# 99338      455
# 99339    1,078
# 99340      103
# 99341      982
# Name: price, Length: 99342, dtype: object

# %%
# Step: Perform a data cleaning or inspection operation
# Why: This step improves data quality before further processing

data["price"] = data["price"].str.replace(",", "")

# %%
# Step: Perform a data cleaning or inspection operation
# Why: This step improves data quality before further processing

data["price"] = data["price"].str.replace(" ", "")

# %%
# Step: Perform a data cleaning or inspection operation
# Why: This step improves data quality before further processing

type(data["price"] [1])
# Out:
# str

# %%
# Step: Convert column data types
# Why: Ensures correct data types for calculations and analysis

data["price"] = data["price"].astype(int)

# %%
# Step: Perform a data cleaning or inspection operation
# Why: This step improves data quality before further processing

type(data["price"] [1])
# Out:
# numpy.int64

# %%
# Step: Perform a data cleaning or inspection operation
# Why: This step improves data quality before further processing

data.to_csv("Cleaned_Airbnb_Data.csv")

# %%
# Step: Load raw Airbnb CSV data into a pandas DataFrame
# Why: This initializes the dataset so we can inspect and clean it further

pd.read_csv("Cleaned_Airbnb_Data.csv")
# Out:
#        Unnamed: 0   index                                              Name  \
# 0               0       0                Clean & quiet apt home by the park
# 1               1       1                             Skylit Midtown Castle
# 2               2       4  Entire Apt: Spacious Studio/Loft by central park
# 3               3       5         Large Cozy 1 BR Apartment In Midtown East
# 4               4       7                                   BlissArtsSpace!
# ...           ...     ...                                               ...
# 99337       99337  102029            Cozy room in a 2B with backyard access
# 99338       99338  102030                      An East Williamsburg Delight
# 99339       99339  102031                      Cozy bedroom in williamsburg
# 99340       99340  102032                            Spacious Room w/ 2 Bed
# 99341       99341  102040                     Room in Queens, NY, near LGA.
#
# ...

# %%
# Step: Perform a data cleaning or inspection operation
# Why: This step improves data quality before further processing

data.to_excel("Excel_cleaned_airbnb_data.xlsx", index = False)

# %%
# Step: Perform a data cleaning or inspection operation
# Why: This step improves data quality before further processing

pd.read_excel("Excel_cleaned_airbnb_data.xlsx")
# Out:
#         index                                              Name      host id  \
# 0           0                Clean & quiet apt home by the park  80014485718
# 1           1                             Skylit Midtown Castle  52335172823
# 2           4  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3           5         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4           7                                   BlissArtsSpace!  90821839709
# ...       ...                                               ...          ...
# 99337  102029            Cozy room in a 2B with backyard access   5155155913
# 99338  102030                      An East Williamsburg Delight  71564706996
# 99339  102031                      Cozy bedroom in williamsburg  83101851929
# 99340  102032                            Spacious Room w/ 2 Bed  69037598918
# 99341  102040                     Room in Queens, NY, near LGA.  56457739998
#
# ...
